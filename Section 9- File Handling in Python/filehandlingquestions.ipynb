# %% [markdown]
# # Module: File Handling Assignments
# ## Lesson: File Handling and Operations

# %% [markdown]
# ### Assignment 1: Reading a File
#
# Write a function that reads the contents of a file named `sample.txt` and prints each line.

# %%
def read_file(filename):
    with open(filename, 'r') as file:
        content = file.readlines()
        for row in content:
            print(row)

read_file("sample.txt")
# Out:
# [2026-03-26 08:15:01] INFO: System booted successfully.
#
# [2026-03-26 08:15:05] INFO: Starting user authentication service...
#
# [2026-03-26 09:30:12] WARNING: High CPU usage detected on web-server-01.
#
# [2026-03-26 09:45:30] ERROR: Failed to connect to the main database at 10.0.0.5.
#
# [2026-03-26 09:46:05] INFO: Retrying database connection...
#
# [2026-03-26 09:46:08] INFO: Database connection re-established successfully.
#
# [2026-03-26 11:00:00] WARNING: User admin_frank failed login attempt (Bad Password).

# %% [markdown]
# ### Assignment 2: Writing to a File
#
# Write a function that writes a list of strings to a file named `output.txt`, with each string on a new line.

# %%
list_of_strings = [
    "Introduction: What Social Media Etiquette Means",
    "The Golden Rules of Digital Communication",
    "Case Study: Navigating Conversations on X (Twitter)",
    "Case Study: Maintaining Professionalism on Facebook",
    "Handling Trolls and Online Conflict",
    "Conclusion: Building a Positive Digital Footprint"
]

with open('output.txt', 'w') as file:
    for line in list_of_strings:
        file.write(line + "\n")

print("Finished writing lines")
# Out:
# Finished writing lines

# %% [markdown]
# ### Assignment 3: Copying a File
#
# Write a function that copies the contents of a file named `source.txt` to a new file named `destination.txt`.

# %%
def copy_file(src, dest):
    with open(dest, 'w') as dest:
        with open(src, 'r') as source:
            dest.write(source.read())

copy_file('source.txt', 'destination.txt')

# %% [markdown]
# ### Assignment 4: Appending to a File
#
# Write a function that appends a given string to the end of a file named `log.txt`.

# %%
def append_file(file, string):
    with open(file, 'a') as dest:
        dest.write('\n' + string)

append_file('log.txt', '[SEVERITY] THIS MAY CRASH')

# %% [markdown]
# ### Assignment 5: Counting Words in a File
#
# Write a function that reads the contents of a file named `document.txt` and returns the number of words in the file.

# %%
def read_content(file):
    with open(file, 'r') as file:
        content = file.read()

        words = content.split()
        return len(words)

print(read_content('document.txt'))
# Out:
# 185

# %% [markdown]
# ### Assignment 6: Finding and Replacing Text
#
# Write a function that finds and replaces all occurrences of a given word in a file named `data.txt` with another word.

# %%
def find_and_replace(old_word, new_word, filename):
    with open(filename, 'r') as file:
        content = file.read()
    new_content = content.replace(old_word, new_word)
    with open(filename, 'w') as dest:
        dest.write(new_content)

find_and_replace("legacy server", "meatpie", "data.txt")

# %% [markdown]
# ### Assignment 7: Reading a File in Reverse
#
# Write a function that reads the contents of a file named `reverse.txt` and prints each line in reverse order.

# %%
def reverselinesintext(filename):
    with open(filename, "r") as file:
        content = file.readlines()
    new_content = reversed(content)
    with open(filename, 'w') as dest:
        new_content = "".join(new_content)
        dest.write(new_content)

reverselinesintext("reverse.txt")

# %% [markdown]
# ### Assignment 8: Counting Lines, Words, and Characters
#
# Write a function that reads the contents of a file named `stats.txt` and returns the number of lines, words, and characters in the file.

# %%
def read_file_contents(filename):
    with open(filename, 'r') as file:
        content = file.readlines()
        lines = len(content)
        words = sum([len(line.split()) for line in content])
        
        char_count = sum([len(_) for _ in content])

        return(lines, words, char_count)
    
print(read_file_contents("stats.txt"))
# Out:
# (3, 21, 98)

# %% [markdown]
# ### Assignment 9: Merging Multiple Files
#
# Write a function that merges the contents of multiple files into a single file named `merged.txt`.

# %%
def merge_content(file_list, output_file):
    with open(output_file, "a") as dest:
        for file_name in file_list:
            with open(file_name, "r") as file:
                content = file.read()
                dest.write(content + "\n")

list_of_files = ["log.txt", "output.txt", "reverse.txt", "stats.txt"]

merge_content(list_of_files, "merged.txt")

# %% [markdown]
# ### Assignment 10: Splitting a Large File
#
# Write a function that splits a large file named `large.txt` into smaller files of 100 lines each.

# %%
# Used this to create a 350 line document to test my function 

# Run this once to build your large.txt file
with open("large.txt", "w") as file:
    for i in range(1, 351):
        # Creates a realistic-looking log line with a line number
        file.write(f"Line {i}: [INFO] GKE Cluster node-{i % 5} health check passed.\n")

print("Success: large.txt has been created with 350 lines!")
# Out:
# Success: large.txt has been created with 350 lines!

# %%
import math

def split_large(file):
    with open(file, 'r') as file:
        content = file.readlines()
        number_of_files = math.ceil(len(content) / 100)
        for _ in range(number_of_files):
            if len(content) < 100 * (_ + 1) :
                    with open(f"file{_}.txt", "w") as dest:
                        dest.write("".join(content[100*_: ]))
            else:
                with open(f"file{_}.txt", "w") as dest:
                    dest.write("".join(content[100*_: 100*(_+1)]))

split_large("large.txt")

# %% [markdown]
# ### Assignment 11: Creating a Log File
#
# Write a function that creates a log file named `activity.log` and writes log messages with timestamps.

# %%
import datetime

def log_message(message, filename='activity.log'):
    timestamp = datetime.datetime.now().isoformat()
    with open(filename, 'a') as file:
        file.write(f'[{timestamp}] {message}\n')

# %% [markdown]
# ### Assignment 12: Binary File Operations
#
# Write a function that reads a binary file named `image.bin` and writes its contents to another binary file named `copy_image.bin`.

# %% [markdown]
# ### Assignment 13: CSV File Operations
#
# Write a function that reads a CSV file named `data.csv` and prints its contents as a list of dictionaries.

# %% [markdown]
# ### Assignment 14: JSON File Operations
#
# Write a function that reads a JSON file named `data.json` and prints its contents as a Python dictionary.

# %% [markdown]
# ### Assignment 15: File Permission Handling
#
# Write a function that attempts to read a file named `protected.txt` and handles any permission errors gracefully by printing an error message.
