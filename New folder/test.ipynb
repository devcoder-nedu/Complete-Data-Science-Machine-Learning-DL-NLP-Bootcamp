# %%
print(1+1)
# Out:
# 2

# %% [markdown]
# ### PYTHON ENVIRONMENT

# %%
age = 30 
if age > 22:
    print("You are above 22")
else:
    print("You are 22 or below")
# Out:
# You are above 22

# %%
for i in range(10,1,-1):
    print(i)
# Out:
# 10
# 9
# 8
# 7
# 6
# 5
# 4
# 3
# 2
