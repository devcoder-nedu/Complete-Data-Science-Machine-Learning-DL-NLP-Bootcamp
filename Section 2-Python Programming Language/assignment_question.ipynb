# %% [markdown]
# # Lesson 1.2: Python Basics
# ## Topics Covered:
# - Syntax and Semantics
# - Variables and Data Types
# - Basic Operators (Arithmetic, Comparison, Logical)

# %% [markdown]
# ## 1. Syntax and Semantics
#
# **Question 1:** Write a Python program to print "Hello, World!".

# %%
print("Hello, World!")
# Out:
# 'Hello, World!'

# %% [markdown]
# **Question 2:** Write a Python program that takes a user input and prints it.

# %%
user_input = input("Please enter something: ")
print(f"You entered: {user_input}")
# Out:
# You entered: Quest ce que

# %% [markdown]
# **Question 3:** Write a Python program to check if a number is positive, negative, or zero.

# %%
num = int(input("Enter a number: "))
print( 'positive' if num > 0 else 'negative' if num < 0 else 'zero' )
# Out:
# negative

# %% [markdown]
# **Question 4:** Write a Python program to find the largest of three numbers.

# %%
group = [int(x) for x in input('Input three numbers separated by a space').split()]
print(f"largest number is {max(group)}")
# Out:
# largest number is 4

# %% [markdown]
# **Question 5:** Write a Python program to calculate the factorial of a number.

# %%
def factorial(num):
    if num == 0 or num == 1:
        return 1
    elif num < 0:
        return "Incorrect use of the factorial function: Can not take a negative number"
    else:
        return num * factorial(num-1)

factorial(int(input("Please input a factorial:")))
# Out:
# 120

# %% [markdown]
# ## 2. Variables and Data Types
#
# **Question 6:** Create variables of different data types: integer, float, string, and boolean. Print their values and types.

# %%
integer, floating, string, boolean = 2, 2.5, "String is a good thing", True

print(f"{integer} is of type: {type(integer)}")
print(f"{string} is of type: {type(string)}")
print(f"{floating} is of type: {type(floating)}")
print(f"{boolean} is of type: {type(boolean)}")
# Out:
# 2 is of type: <class 'int'>
# String is a good thing is of type: <class 'str'>
# 2.5 is of type: <class 'float'>
# True is of type: <class 'bool'>

# %% [markdown]
# **Question 7:** Write a Python program to swap the values of two variables.

# %%
a = 2 
b = 3
print(f"{a} and {b}")

a, b = b, a
print(f"{a} and {b}")
# Out:
# 2 and 3
# 3 and 2

# %% [markdown]
# **Question 8:** Write a Python program to convert Celsius to Fahrenheit.

# %%
def fahrenheitfrmcelsuiscalc(celsuis):
    return celsuis*1.8 +32
fahrenheitfrmcelsuiscalc(20)
# Out:
# 68.0

# %% [markdown]
# **Question 9:** Write a Python program to concatenate two strings.

# %%
string1 = input("Input whatever string you want")
string2 = input("Input whatever string you want")
result = string1+string2
print(result)
# Out:
# fwarfheuafhr gwaigtfiaerigagra5g geighaigrfbiqrwgbrugbfaeru gteubrgu rgauabrgraug

# %% [markdown]
# **Question 10:** Write a Python program to check if a variable is of a specific data type.

# %%
def type_checker(variable, type):
    print(isinstance(variable, type))

print(type(2))
type_checker(2, int)
# Out:
# <class 'int'>
# True

# %% [markdown]
# ## 3. Basic Operators (Arithmetic, Comparison, Logical)
#
# **Question 11:** Write a Python program to perform arithmetic operations: addition, subtraction, multiplication, and division.

# %%
a = 5
b = 3

print(f"Addition: {a} + {b} = {a + b}")
print(f"Subtraction: {a} - {b} = {a - b}")
print(f"Multiplication: {a} * {b} = {a * b}")
print(f"Division: {a} / {b} = {a / b}")

# %% [markdown]
# **Question 12:** Write a Python program to demonstrate comparison operators: equal to, not equal to, greater than, less than.

# %%
a = 5
b = 3

print(f"{a} == {b}: {a == b}")
print(f"{a} != {b}: {a != b}")
print(f"{a} > {b}: {a > b}")
print(f"{a} < {b}: {a < b}")

# %% [markdown]
# **Question 13:** Write a Python program to demonstrate logical operators: and, or, not.

# %%
a = False
b = True

print(a and b)
print(a or b)
print(not a)
# Out:
# False
# True
# True

# %% [markdown]
# **Question 14:** Write a Python program to calculate the square of a number.

# %%
def square(n):
    return n ** 2

square(5)
# Out:
# 25

# %% [markdown]
# **Question 15:** Write a Python program to check if a number is even or odd.

# %%
print("even" if int(input("Input a number"))%2 == 0 else "odd")
# Out:
# odd

# %% [markdown]
# **Question 16:** Write a Python program to find the sum of the first n natural numbers.

# %%
def summationofnaturalnumbers(n):
    return n * (n+1)/2

summationofnaturalnumbers(6)
# Out:
# 21.0

# %% [markdown]
# **Question 17:** Write a Python program to check if a year is a leap year.

# %%
def isaleapyear(year):
    if (year % 4 == 0 and year % 100 != 0) or year % 400 == 0:
        print('It is a leap year')
    else:
        print("It is not a leap year")

isaleapyear(int(input("Input a year")))
# Out:
# It is not a leap year

# %% [markdown]
# **Question 18:** Write a Python program to reverse a string.

# %%
string = input("Please, input a string to be used")
print(string[::-1])
# Out:
# NAMA

# %% [markdown]
# **Question 19:** Write a Python program to check if a string is a palindrome.

# %%
string = input("Please, input a string to be used")
print(string == string[::-1])
# Out:
# True

# %% [markdown]
# **Question 20:** Write a Python program to sort a list of numbers in ascending order.

# %%
list = [23,12,45,23,41,36,87,43]
list.sort()
print(list)
# Out:
# [12, 23, 23, 36, 41, 43, 45, 87]
